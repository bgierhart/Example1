# %%
import random
import matplotlib.pyplot as plt

# %%
numbers = [4,5,6,7,2,3,5,4,3]

# %%
plt.hist(numbers)
# Out:
# (array([1., 0., 2., 0., 2., 0., 2., 0., 1., 1.]),
#  array([2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. ]),
#  <BarContainer object of 10 artists>)

# %%
x = random.randrange(10)

# %%
print(x)
# Out:
# 8

# %%
for i in range(99):
    x = random.randrange(10,1000)
    print(x, end=" ")
# Out:
# 71 390 365 91 654 614 51 883 693 848 527 63 556 799 589 492 956 435 243 412 560 982 700 473 110 147 790 329 230 89 887 793 324 21 47 933 34 456 545 522 734 498 96 440 381 152 134 945 439 678 24 925 53 472 202 676 450 766 426 303 575 672 573 585 705 967 126 602 23 602 532 804 448 21 820 215 744 322 37 504 823 969 985 530 795 264 606 598 511 290 15 601 289 224 972 289 940 291 182

# %%
for i in range(1000): #this creates an empty list
    x = random.range(10)
    numbers.append(x)
    #print(x, end=" ")
